# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %matplotlib inline

# %% [markdown]
# This project is a classification project to identify fraud with machine learning. It is inspired by Emmanuel Ikogho's medium article "Classification Project- Fraud Detection". I will be using the csv from that article.

# %%
df=pd.read_csv('Fraud.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
#Renaming Columns for better readability and understanding
df.rename(columns={'step':'time_step', 
                   'type':'trans_type',
                   'amount':'trans_amount',
                   'nameOrig':'cust_orig',
                   'oldbalanceOrg': 'old_orig_bal',
                   'newbalanceOrig': 'new_orig_bal',
                   'nameDest': 'cust_dest',
                   'oldbalanceDest': 'old_dest_bal',
                   'newbalanceDest': 'new_dest_bal'
}, inplace=True)

# %%
df.head()
# Out:
#    time_step trans_type  trans_amount    cust_orig  old_orig_bal  \
# 0          1    PAYMENT       9839.64  C1231006815      170136.0
# 1          1    PAYMENT       1864.28  C1666544295       21249.0
# 2          1   TRANSFER        181.00  C1305486145         181.0
# 3          1   CASH_OUT        181.00   C840083671         181.0
# 4          1    PAYMENT      11668.14  C2048537720       41554.0
#
#    new_orig_bal    cust_dest  old_dest_bal  new_dest_bal  isFraud  \
# 0     160296.36  M1979787155           0.0           0.0        0
# 1      19384.72  M2044282225           0.0           0.0        0
# 2          0.00   C553264065           0.0           0.0        1
# 3          0.00    C38997010       21182.0           0.0        1
# 4      29885.86  M1230701703           0.0           0.0        0
#
#    isFlaggedFraud
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
